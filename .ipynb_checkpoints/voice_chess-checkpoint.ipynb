# %%
# !pip install SpeechRecognition
import speech_recognition as sr

r = sr.Recognizer()
sr.Microphone.list_microphone_names()
mic = sr.Microphone(device_index=1)

from win32com.client import constants, Dispatch

speaker = Dispatch("SAPI.SpVoice")

from stockfish import Stockfish

stockfish = Stockfish("C://Users//anupk//Downloads//stockfish_14_win_x64//stockfish_14_x64")

# %%
# ! pip install pyaudio
# import pyaudio
# !pip install pypiwin32
# ! pip install stockfish

# %%
from random import random
import re 
import sys

from IPython.display import clear_output

regex = '([a-h])([1-8])([a-h])([1-8])'

def check(move):
    global speaker
    
    if move == 'stop':
        return -1
    
    if stockfish.is_move_correct(move):
        
        if(re.search(regex,move)):

            speaker.Speak(move)
            return 1
        
        else:
            return 0
    else:
        return 0
    

def config_engine(elo = 1000, skill_lvl = 12, depth = 15):
    stockfish.set_skill_level(skill_lvl)
    stockfish.set_elo_rating(elo)
    stockfish.set_depth(depth)


def choose_player_color():
    if random() > 0.5:
        return 'white'
    else:
        return 'black'
    
def human_move(speak_flag):
    
    if speak_flag == True:
        print("call out")
        global speaker
        speaker.Speak("Your turn")
        try:
            with mic as source:
                audio = r.listen(source)
            h_move = r.recognize_google(audio)
            h_move = h_move.replace(" ","")
            h_move = h_move.lower()
            valid = check(h_move)

            if valid == 1:
                return h_move

            elif valid == -1:
                sys.exit()
                
            else:
                speaker.Speak("speak clearly!!!")
                human_move()
        except:
            speaker.Speak("speak clearly!!!")
            human_move()
    
    else:
        print("command please")
        h_move = input("Enter your move: ")
        valid = check(h_move)
        if valid == 1:
            return h_move
        
        elif valid == -1:
            sys.exit()
        
        else:
            speaker.Speak("check the format")
            human_move(False)
            

def engine_move():
    e_move = stockfish.get_best_move()
    speaker.Speak(e_move)
    return e_move



def display_current_positions(moves):
    stockfish.set_position(moves)
    clear_output(wait=True)
    print(moves)
    viz = stockfish.get_board_visual().split('\n')
    viz.append('--A---B---C---D---E---F---G---H--')
    for i in viz:
        print(i)

# %%
player_turn = -1
game_moves = []
voice = False
import time


def play_game():
    global voice
    rating = input("set elo rating: [default : 1000]")
    if rating:
        config_engine(elo =rating)
    player_color = choose_player_color()
    print("you are playing as ",player_color)
    play_type = input("enter voice or key :")
    voice = True if play_type == "voice" else False
    player_turn = 1 if player_color == "white" else 0
    
    while True: #checkmate condition needed
        try:
            display_current_positions(game_moves)
            if player_turn == 1 :
                hm_mv = human_move(voice)
                if hm_mv != None:
                    game_moves.append(hm_mv)
                    print(game_moves)
                    display_current_positions(game_moves)
                    player_turn = 0
                
            if player_turn == 0:
                game_moves.append(engine_move())
                print(game_moves)
                display_current_positions(game_moves)
                player_turn = 1
                
#             print(game_moves)
        except Exception as e:
            print(e)

# %%
play_game()
# Out:
# ['e2e4', 'e7e5', 'b1c3', 'g8f6', 'g2g3', 'd7d6', 'd2d4', 'e5d4', 'c3e2', 'c8g4', 'd1d4']
# +---+---+---+---+---+---+---+---+
# | r | n |   | q | k | b |   | r | 8
# +---+---+---+---+---+---+---+---+
# | p | p | p |   |   | p | p | p | 7
# +---+---+---+---+---+---+---+---+
# |   |   |   | p |   | n |   |   | 6
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   |   |   |   | 5
# +---+---+---+---+---+---+---+---+
# |   |   |   | Q | P |   | b |   | 4
# +---+---+---+---+---+---+---+---+
# |   |   |   |   |   |   | P |   | 3
# +---+---+---+---+---+---+---+---+
# | P | P | P |   | N | P |   | P | 2
# +---+---+---+---+---+---+---+---+
# | R |   | B |   | K | B | N | R | 1
# +---+---+---+---+---+---+---+---+
#
# --A---B---C---D---E---F---G---H--
# command please
# Enter your move: stop
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\anupk\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
